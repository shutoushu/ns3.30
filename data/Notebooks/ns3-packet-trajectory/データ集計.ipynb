# %%
import pandas as pd
import cv2
import numpy as np
import matplotlib.pyplot as plt
#jupyter内で画像を表示
# %matplotlib inline 
#別ウィンドウで画像表示
# %matplotlib qt 
import csv
import json
from ipywidgets import interact, interactive, fixed, RadioButtons
import ipywidgets as widgets
from IPython.display import display
import pathlib
import glob
import re
import copy

# %%
shadow = 'shadow20_2'
evaluation_path = "../../get_data/Horizontal_axis/" + shadow + "/"
sigo_file_list = []
# sigo_files = glob.glob("../../ns3.30/data/sigo/*")
sigo_files = glob.glob(evaluation_path + "sigo/*")
for file in sigo_files:
    sigo_file_list.append(file)
    
send_sigo_file_list = []
# send_sigo_files = glob.glob("../../ns3.30/data/send_sigo/*")
send_sigo_files = glob.glob(evaluation_path + "send_sigo/*")
for file in send_sigo_files:
    send_sigo_file_list.append(file)
print('receive log')
print(sigo_file_list)
print('send log')
print(send_sigo_file_list)
# Out:
# receive log
# ['../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10001nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10001nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10001nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10002nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10002nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10002nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10003nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10003nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10003nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10004nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10004nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10004nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10005nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10005nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10005nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10006nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10006nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10006nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10007nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10007nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10007nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10008nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10008nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10008nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10009nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10009nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10009nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10010nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10010nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10010nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10011nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10011nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10011nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10012nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10012nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10012nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10013nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10013nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10013nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10014nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10014nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10014nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10015nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10015nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10015nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10016nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10016nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10016nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_1001 ...
# send log
# ['../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10001nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10001nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10001nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10002nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10002nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10002nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10003nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10003nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10003nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10004nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10004nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10004nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10005nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10005nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10005nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10006nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10006nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10006nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10007nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10007nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10007nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10008nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10008nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10008nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10009nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10009nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10009nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10010nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10010nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10010nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10011nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10011nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10011nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10012nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10012nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10012nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10013nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10013nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10013nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10014nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10014nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10014nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10015nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10015nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10015nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10016nodenum_200.csv ...

# %%
lsgo_file_list = []
# lsgo_files = glob.glob("../../ns3.30/data/lsgo/*")
lsgo_files = glob.glob(evaluation_path + "lsgo/*")
for file in lsgo_files:
    lsgo_file_list.append(file)
    
send_lsgo_file_list = []
# send_lsgo_files = glob.glob("../../ns3.30/data/send_lsgo/*")
send_lsgo_files = glob.glob(evaluation_path + "send_lsgo/*")
for file in send_lsgo_files:
    send_lsgo_file_list.append(file)
print('receive log')
print(lsgo_file_list)
print('send log')
print(send_lsgo_file_list)
# Out:
# receive log
# ['../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10001nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10001nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10001nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10002nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10002nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10002nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10003nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10003nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10003nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10004nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10004nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10004nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10005nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10005nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10005nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10006nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10006nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10006nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10007nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10007nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10007nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10008nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10008nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10008nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10009nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10009nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10009nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10010nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10010nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10010nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10011nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10011nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10011nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10012nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10012nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10012nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10013nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10013nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10013nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10014nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10014nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10014nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10015nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10015nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10015nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10016nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10016nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10016nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_1001 ...
# send log
# ['../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10001nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10001nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10001nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10002nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10002nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10002nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10003nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10003nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10003nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10004nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10004nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10004nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10005nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10005nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10005nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10006nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10006nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10006nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10007nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10007nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10007nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10008nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10008nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10008nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10009nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10009nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10009nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10010nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10010nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10010nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10011nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10011nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10011nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10012nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10012nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10012nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10013nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10013nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10013nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10014nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10014nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10014nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10015nodenum_200.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10015nodenum_300.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10015nodenum_400.csv', '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10016nodenum_200.csv ...

# %% [markdown]
# # seed値とノード数のリストを作成する

# %%
seed_index = 2
node_index = 3
seed_list = []
nodenum_list = ['200', '300', '400'] ###############nodenumの形式を変更したらここはベタ打ちで変更を加える
regex = re.compile('\d+')

for path in sigo_file_list:
    for line in path.splitlines():
        match = regex.findall(line)
        if match[seed_index] not in seed_list:
            seed_list.append(match[seed_index])
            
print(seed_list)
print('simulation 試行回数',len(seed_list))
# Out:
# ['10001', '10002', '10003', '10004', '10005', '10006', '10007', '10008', '10009', '10010', '10011', '10012', '10013', '10014', '10015', '10016', '10017', '10018', '10019', '10020', '10021', '10022', '10023', '10024', '10025', '10026', '10027', '10028', '10029', '10030', '10031', '10032', '10033', '10034', '10035', '10036', '10037', '10038', '10039', '10040', '10041', '10042', '10043', '10044', '10045', '10046', '10047', '10048', '10049', '10050', '10051', '10052', '10053', '10054', '10055', '10056', '10057', '10058', '10059', '10060', '10061', '10062', '10063', '10064', '10065', '10066', '10067', '10068', '10069', '10070', '10071', '10072', '10073', '10074', '10075', '10076', '10077', '10078', '10079', '10080', '10081', '10082', '10083', '10084', '10085', '10086', '10087', '10088', '10089', '10090', '10091', '10092', '10093', '10094', '10095', '10096', '10097', '10098', '10099']
# simulation 試行回数 99

# %% [markdown]
#    # seed値にノード数をネストした辞書配列を作成
# https://www.it-swarm-ja.tech/ja/python/python%E3%81%A7%E3%83%8D%E3%82%B9%E3%83%88%E3%81%95%E3%82%8C%E3%81%9F%E8%BE%9E%E6%9B%B8%E3%82%92%E3%81%A9%E3%81%AE%E3%82%88%E3%81%86%E3%81%AB%E4%BD%9C%E6%88%90%E3%81%97%E3%81%BE%E3%81%99%E3%81%8B%EF%BC%9F/1072031996

# %%
sigo_dict = {}
check_seed = seed_list[0]
sigo_dict[check_seed] = {}
for path in sigo_file_list:
    for line in path.splitlines():
      match = regex.findall(line) # match[2] = seed ,match[3] = nudenum
     
    if match[seed_index] == check_seed:
        sigo_dict[match[seed_index]][match[node_index]] = path
    else:#ロープ中seed値が変わるとき
        sigo_dict[match[seed_index]] = {}
        sigo_dict[match[seed_index]][match[node_index]] = path
        check_seed = match[seed_index] #seed値の更新
        
send_sigo_dict = {}
check_seed = seed_list[0]
send_sigo_dict[check_seed] = {}
for path in send_sigo_file_list:
    for line in path.splitlines():
      match = regex.findall(line) # match[2] = seed ,match[3] = nudenum
     
    if match[seed_index] == check_seed:
        send_sigo_dict[match[seed_index]][match[node_index]] = path
    else:#ロープ中seed値が変わるとき
        send_sigo_dict[match[seed_index]] = {}
        send_sigo_dict[match[seed_index]][match[node_index]] = path
        check_seed = match[seed_index] #seed値の更新
        

print(sigo_dict)
print(send_sigo_dict)
# Out:
# {'10001': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10001nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10001nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10001nodenum_400.csv'}, '10002': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10002nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10002nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10002nodenum_400.csv'}, '10003': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10003nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10003nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10003nodenum_400.csv'}, '10004': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10004nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10004nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10004nodenum_400.csv'}, '10005': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10005nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10005nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10005nodenum_400.csv'}, '10006': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10006nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10006nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10006nodenum_400.csv'}, '10007': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10007nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10007nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10007nodenum_400.csv'}, '10008': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10008nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10008nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10008nodenum_400.csv'}, '10009': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10009nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10009nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10009nodenum_400.csv'}, '10010': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10010nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10010nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10010nodenum_400.csv'}, '10011': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10011nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10011nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10011nodenum_400.csv'}, '10012': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10012nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10012nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10012nodenum_400.csv'}, '10013': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10013nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10013nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10013nodenum_400.csv'}, '10014': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10014nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10014nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10014nodenum_400.csv'}, '10015': {'200': '../../get_data/Horizontal_axis/shadow20_2/sigo\\sigo-seed_10015nodenum_200.csv', '300': ' ...
# {'10001': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10001nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10001nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10001nodenum_400.csv'}, '10002': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10002nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10002nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10002nodenum_400.csv'}, '10003': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10003nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10003nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10003nodenum_400.csv'}, '10004': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10004nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10004nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10004nodenum_400.csv'}, '10005': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10005nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10005nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10005nodenum_400.csv'}, '10006': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10006nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10006nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10006nodenum_400.csv'}, '10007': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10007nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10007nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10007nodenum_400.csv'}, '10008': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10008nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10008nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10008nodenum_400.csv'}, '10009': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10009nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10009nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10009nodenum_400.csv'}, '10010': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10010nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10010nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10010nodenum_400.csv'}, '10011': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10011nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10011nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10011nodenum_400.csv'}, '10012': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10012nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10012nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10012nodenum_400.csv'}, '10013': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10013nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10013nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10013nodenum_400.csv'}, '10014': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10014nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_sigo\\sigo-seed_10014nodenum_30 ...

# %%
lsgo_dict = {}
check_seed = seed_list[0]
lsgo_dict[check_seed] = {}
for path in lsgo_file_list:
    for line in path.splitlines():
      match = regex.findall(line) # match[2] = seed ,match[3] = nudenum
     
    if match[seed_index] == check_seed:
        lsgo_dict[match[seed_index]][match[node_index]] = path
    else:#ロープ中seed値が変わるとき
        lsgo_dict[match[seed_index]] = {}
        lsgo_dict[match[seed_index]][match[node_index]] = path
        check_seed = match[seed_index] #seed値の更新
        
send_lsgo_dict = {}
check_seed = seed_list[0]
send_lsgo_dict[check_seed] = {}
for path in send_lsgo_file_list:
    for line in path.splitlines():
      match = regex.findall(line) # match[2] = seed ,match[3] = nudenum
     
    if match[seed_index] == check_seed:
        send_lsgo_dict[match[seed_index]][match[node_index]] = path
    else:#ロープ中seed値が変わるとき
        send_lsgo_dict[match[seed_index]] = {}
        send_lsgo_dict[match[seed_index]][match[node_index]] = path
        check_seed = match[seed_index] #seed値の更新
        
print(lsgo_dict)
print(send_lsgo_dict)
# Out:
# {'10001': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10001nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10001nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10001nodenum_400.csv'}, '10002': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10002nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10002nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10002nodenum_400.csv'}, '10003': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10003nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10003nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10003nodenum_400.csv'}, '10004': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10004nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10004nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10004nodenum_400.csv'}, '10005': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10005nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10005nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10005nodenum_400.csv'}, '10006': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10006nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10006nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10006nodenum_400.csv'}, '10007': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10007nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10007nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10007nodenum_400.csv'}, '10008': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10008nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10008nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10008nodenum_400.csv'}, '10009': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10009nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10009nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10009nodenum_400.csv'}, '10010': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10010nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10010nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10010nodenum_400.csv'}, '10011': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10011nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10011nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10011nodenum_400.csv'}, '10012': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10012nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10012nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10012nodenum_400.csv'}, '10013': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10013nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10013nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10013nodenum_400.csv'}, '10014': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10014nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10014nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10014nodenum_400.csv'}, '10015': {'200': '../../get_data/Horizontal_axis/shadow20_2/lsgo\\lsgo-seed_10015nodenum_200.csv', '300': ' ...
# {'10001': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10001nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10001nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10001nodenum_400.csv'}, '10002': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10002nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10002nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10002nodenum_400.csv'}, '10003': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10003nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10003nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10003nodenum_400.csv'}, '10004': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10004nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10004nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10004nodenum_400.csv'}, '10005': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10005nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10005nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10005nodenum_400.csv'}, '10006': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10006nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10006nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10006nodenum_400.csv'}, '10007': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10007nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10007nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10007nodenum_400.csv'}, '10008': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10008nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10008nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10008nodenum_400.csv'}, '10009': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10009nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10009nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10009nodenum_400.csv'}, '10010': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10010nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10010nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10010nodenum_400.csv'}, '10011': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10011nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10011nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10011nodenum_400.csv'}, '10012': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10012nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10012nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10012nodenum_400.csv'}, '10013': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10013nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10013nodenum_300.csv', '400': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10013nodenum_400.csv'}, '10014': {'200': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10014nodenum_200.csv', '300': '../../get_data/Horizontal_axis/shadow20_2/send_lsgo\\lsgo-seed_10014nodenum_30 ...

# %% [markdown]
# # パケット到達率を返す関数

# %%
def packet_ratio(path):
    #csvファイルの取得
    path_df = pd.read_csv(path)
    dest_list = path_df['destination_id'].value_counts().index.tolist() #重複なしのdestination_idを格納
    #目的地に届いたidだけをlistに保存
    reach_list = path_df[path_df['recv_id'] == path_df['destination_id']]['destination_id'].value_counts().index.tolist()
#     PDR = len(reach_list)/len(dest_list)
    PDR = len(reach_list)/10
    
#     *************** len(dest_list): destination_idのリストをいったん10個で定義
    return PDR

# %% [markdown]
# # hop数平均を返す関数

# %%
def packet_hop(path):
    path_df = pd.read_csv(path)
    dest_list = path_df['destination_id'].value_counts().index.tolist() #重複なしのdestination_idを格納
    #目的地に届いたidだけをlistに保存
    reach_list = path_df[path_df['recv_id'] == path_df['destination_id']]['destination_id'] 
    #reach_listを回す
    total_hop = 0
    for reach_id in reach_list:
        hop = path_df[(path_df['destination_id'] == reach_id) & (path_df['destination_id'] == path_df['recv_id'])]['hopcount']
        hop = int(hop.head(1).iloc[-1])
        total_hop += hop
    if(len(reach_list) != 0):
        average_hop = total_hop / len(reach_list)
    else:
        average_hop = total_hop
    
    return average_hop

# %% [markdown]
# # エンドツーエンド遅延(平均)を返す関数

# %%
def packet_delay(path):
    delay_list = []
    #csvファイルの取得
    path_df = pd.read_csv(path)
    #目的地に届いたidだけをlistに保存
    reach_list = path_df[path_df['recv_id'] == path_df['destination_id']]['destination_id'].value_counts().index.tolist()
    #reach_listを回す
    if (len(reach_list) == 0):
        delay = 0
        print('reach_list none')
        return delay
    for reach_id in reach_list:
        source_time = path_df[path_df['destination_id'] == reach_id]['time']
        recv_time = path_df[(path_df['destination_id'] == reach_id) & (path_df['destination_id'] == path_df['recv_id'])]['time']
        delay = int(recv_time.head(1).iloc[-1]) - int(source_time.head(1).iloc[-1])
        delay = delay / 1000000
        delay_list.append(delay)
    delay_mean = np.mean(delay_list)
    return delay_mean

# %% [markdown]
# # オーバーヘッドを返す関数

# %%
def packet_over_head_send(send_path, recv_path):
    send_path_df = pd.read_csv(send_path)
    send_column_num = len(send_path_df.columns) #カラム数を取得
#     display(path_df.iloc[:,send_column_num-1]) 末尾の取得方法　path_df = pd.read_csv(recv_path)末尾=送信ログ(送信したかどうか)
    #目的地に届いたidだけをlistに保存
    recv_path_df = pd.read_csv(recv_path)
    reach_list = recv_path_df[recv_path_df['recv_id'] == recv_path_df['destination_id']]['destination_id'].value_counts().index.tolist()
    send_count = send_path_df[send_path_df.iloc[:,send_column_num-1] == 1].value_counts() #最後のカラムの値が1
#     print(len(send_count))
    if(len(reach_list) != 0):
        overhead = len(send_count)/len(reach_list)
    else:
        overhead = len(send_count)
    return overhead

# %% [markdown]
# # 列ごとの平均を返す関数

# %%
def col_average(seeds):
    new_list = []
    for seed in seeds:
        del seed[len(nodenum_list)] #1列ずつ平均を算出するうえで邪魔なseed値を消していく seedの個数 
        new_list.append(seed)
#     np.set_printoptions(precision=3, suppress=True)
    np_new_list = np.array(new_list)
    return np.mean(np_new_list, axis=0)

# %% [markdown]
# # 出力
# https://techacademy.jp/magazine/15638

# %%
def header(protocol, writer, index):
    writer.writerow([])
    writer.writerow([protocol, index])
    writer.writerow(['200','300','400','seed'])

# %%
def write(seeds):
    for seed in seeds:
        writer.writerow(seed)

with open(evaluation_path + '/100timePerformance_evaluation_6_3.csv', 'w', newline='') as csv_file:
    #---------------------------PDR---------------------------
    sigo_pdr_average_list = []
    lsgo_pdr_average_list = []
    sigo_delay_average_list = []
    lsgo_delay_average_list = []
    sigo_overhead_average_list = []
    lsgo_overhead_average_list = []
    sigo_hop_average_list = []
    lsgo_hop_average_list = []
    
    #headerを設定
    writer = csv.writer(csv_file)
    header('SIGO', writer, 'PDR')
    #--sigo--#
    for seed in seed_list:
        sigo_pdr_ratio_list = []
        for node in nodenum_list:
            path = sigo_dict[seed][node]
            ratio = packet_ratio(path)
            sigo_pdr_ratio_list.append(ratio)
        sigo_pdr_ratio_list.append(seed)
        writer.writerow(sigo_pdr_ratio_list)
        sigo_pdr_average_list.append(sigo_pdr_ratio_list)
    #--lsgo---#
    header('LSGO', writer, 'PDR')
    for seed in seed_list:
        lsgo_pdr_ratio_list = []
        for node in nodenum_list:
            path = lsgo_dict[seed][node]
            ratio = packet_ratio(path)
            lsgo_pdr_ratio_list.append(ratio)
        lsgo_pdr_ratio_list.append(seed)
        writer.writerow(lsgo_pdr_ratio_list)
        lsgo_pdr_average_list.append(lsgo_pdr_ratio_list)
    #------------------------delay-----------------------
    header('SIGO', writer, 'delay')
    #--sigo--#
    for seed in seed_list:
        sigo_delay_list = []
        for node in nodenum_list:
            path = sigo_dict[seed][node]
            delay = packet_delay(path)
            sigo_delay_list.append(delay)
        sigo_delay_list.append(seed)
        writer.writerow(sigo_delay_list)
        sigo_delay_average_list.append(sigo_delay_list)
    #--lsgo--#
    header('LSGO', writer, 'delay')
    for seed in seed_list:
        lsgo_delay_list = []
        for node in nodenum_list:
            path = lsgo_dict[seed][node]
            delay = packet_delay(path)
            lsgo_delay_list.append(delay)
        lsgo_delay_list.append(seed)
        writer.writerow(lsgo_delay_list)

        lsgo_delay_average_list.append(lsgo_delay_list)
#         print('lsgo_delay_average_list', lsgo_delay_average_list)       
    #------------------------overhead-----------------------
    header('SIGO', writer, 'Overhead')
    #--sigo--#
    for seed in seed_list:
        sigo_overhead_list = []
        for node in nodenum_list:
            recv_path = sigo_dict[seed][node]
            print(seed)
            send_path = send_sigo_dict[seed][node]
#             print('path', 'seed', seed)
            overhead = packet_over_head_send(send_path, recv_path)
            sigo_overhead_list.append(overhead)
        sigo_overhead_list.append(seed)
        writer.writerow(sigo_overhead_list)
        sigo_overhead_average_list.append(sigo_overhead_list)
    #--lsgo--#
    header('LSGO', writer, 'Overhead')
    for seed in seed_list:
        lsgo_overhead_list = []
        for node in nodenum_list:
            recv_path = lsgo_dict[seed][node]
            send_path = send_lsgo_dict[seed][node]
            overhead = packet_over_head_send(send_path, recv_path)
            lsgo_overhead_list.append(overhead)
        lsgo_overhead_list.append(seed)
        writer.writerow(lsgo_overhead_list)
        lsgo_overhead_average_list.append(lsgo_overhead_list)
        
    #------------------------Hop-----------------------
    header('SIGO', writer, 'Hop')
    #--sigo--#
    for seed in seed_list:
        sigo_hop_list = []
        for node in nodenum_list:
            path = sigo_dict[seed][node]
            hop = packet_hop(path)
            sigo_hop_list.append(hop)
        sigo_hop_list.append(seed)
        writer.writerow(sigo_hop_list)
        sigo_hop_average_list.append(sigo_hop_list)
    #--lsgo--#
    header('LSGO', writer, 'Hop')
    for seed in seed_list:
        lsgo_hop_list = []
        for node in nodenum_list:
            path = lsgo_dict[seed][node]
            hop = packet_hop(path)
            lsgo_hop_list.append(hop)
        lsgo_hop_list.append(seed)
        writer.writerow(lsgo_hop_list)
        lsgo_hop_average_list.append(lsgo_hop_list)
        
    header('SIGO↑LSGO↓', writer , 'PDR-average')
    writer.writerow(col_average(sigo_pdr_average_list))
#     header('LSGO', writer, 'PDR-average')
    writer.writerow(col_average(lsgo_pdr_average_list))
    header('SIGO↑LSGO↓', writer , 'delay-average')
    writer.writerow(col_average(sigo_delay_average_list))
#     header('LSGO', writer , 'delay-average')
    writer.writerow(col_average(lsgo_delay_average_list))
    header('SIGO↑LSGO↓', writer , 'overhead-average')
    writer.writerow(col_average(sigo_overhead_average_list))
#     header('LSGO', writer , 'overhead-average')
    writer.writerow(col_average(lsgo_overhead_average_list))
    header('SIGO↑LSGO↓', writer , 'hop-average')
    writer.writerow(col_average(sigo_hop_average_list))
#     header('LSGO', writer , 'hop-average')
    writer.writerow(col_average(lsgo_hop_average_list))
    print('finish')
# Out:
# reach_list none
# reach_list none
# reach_list none
# 10001
# 10001
# 10001
# 10002
# 10002
# 10002
# 10003
# 10003
# 10003
# 10004
# 10004
# 10004
# 10005
# 10005
# 10005
# 10006
# 10006
# 10006
# 10007
# 10007
# 10007
# 10008
# 10008
# 10008
# 10009
# 10009
# 10009
# 10010
# 10010
# 10010
# 10011
# 10011
# 10011
# 10012
# 10012
# 10012
# 10013
# 10013
# 10013
# 10014
# 10014
# 10014
# 10015
# 10015
# 10015
# 10016
# 10016
# 10016
# 10017
# 10017
# 10017
# 10018
# 10018
# 10018
# 10019
# 10019
# 10019
# 10020
# 10020
# 10020
# 10021
# 10021
# 10021
# 10022
# 10022
# 10022
# 10023
# 10023
# 10023
# 10024
# 10024
# 10024
# 10025
# 10025
# 10025
# 10026
# 10026
# 10026
# 10027
# 10027
# 10027
# 10028
# 10028
# 10028
# 10029
# 10029
# 10029
# 10030
# 10030
# 10030
# 10031
# 10031
# 10031
# 10032
# 10032
# 10032
# 10033
# 10033
# 10033
# 10034
# 10034
# 10034
# 10035
# 10035
# 10035
# 10036
# 10036
# 10036
# 10037
# 10037
# 10037
# 10038
# 10038
# 10038
# 10039
# 10039
# 10039
# 10040
# 10040
# 10040
# 10041
# 10041
# 10041
# 10042
# 10042
# 10042
# 10043
# 10043
# 10043
# 10044
# 10044
# 10044
# 10045
# 10045
# 10045
# 10046
# 10046
# 10046
# 10047
# 10047
# 10047
# 10048
# 10048
# 10048
# 10049
# 10049
# 10049
# 10050
# 10050
# 10050
# 10051
# 10051
# 10051
# 10052
# 10052
# 10052
# 10053
# 10053
# 10053
# 10054
# 10054
# 10054
# 10055
# 10055
# 10055
# 10056
# 10056
# 10056
# 10057
# 10057
# 10057
# 10058
# 10058
# 10058
# 10059
# 10059
# 10059
# 10060
# 10060
# 10060
# 10061
# 10061
# 10061
# 10062
# 10062
# 10062
# 10063
# 10063
# 10063
# 10064
# 10064
# 10064
# 10065
# 10065
# 10065
# 10066
# 10066
# 10066
# 10067
# 10067
# 10067
# 10068
# 10068
# 10068
# 10069
# 10069
# 10069
# 10070
# 10070
# 10070
# 10071
# 10071
# 10071
# 10072
# 10072
# 10072
# 10073
# 10073
# 10073
# 10074
# 10074
# 10074
# 10075
# 10075
# 10075
# 10076
# 10076
# 10076
# 10077
# 10077
# 10077
# 10078
# 10078
# 10078
# 10079
# 10079
# 10079
# 10080
# 10080
# 10080
# 10081
# 10081
# 10081
# 10082
# 10082
# 10082
# 10083
# 10083
# 10083
# 10084
# 10084
# 10084
# 10085
# 10085
# 10085
# 10086
# 10086
# 10086
# 10087
# 10087
# 10087
# 10088
# 10088
# 10088
# 10089
# 10089
# 10089
# 10090
# 10090
# 10090
# 10091
# 10091
# 10091
# 10092
# 10092
# 10092
# 10093
# 10093
# 10093
# 10094
# 10094
# 10094
# 10095
# 10095
# 10095
# 10096
# 10096
# 10096
# 10097
# 10097
# 10097
# 10098
# 10098
# 10098
# 10099
# 10099
# 10099
# finish

# %% [markdown]
# # 実行漏れ確認

# %%
#sigo
print('sigo -----------------')
for seed in seed_list:
        sigo_delay_list = []
        for node in nodenum_list:
            if(node not in sigo_dict[seed]):
                print("seed", seed, 'node_num', node)
                
print('lsgo-----------------')
for seed in seed_list:
        lsgo_delay_list = []
        for node in nodenum_list:
            if(node not in lsgo_dict[seed]):
                print("seed", seed, 'node_num', node)
# Out:
# sigo -----------------
# lsgo-----------------
